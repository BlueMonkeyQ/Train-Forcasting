# %%
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
Xtest = pd.read_csv(Path('data/Xtest.csv'))
Xtrain = pd.read_csv(Path('data/Xtrain.csv'))
Ytrain = pd.read_csv(Path('data/Ytrain.csv'))
Ysample = pd.read_csv(Path('data/Ysample.csv'))

Ytrain = Ytrain.loc[:, ~Ytrain.columns.str.contains('^Unnamed')]
Xtrain = Xtrain.merge(Ytrain, left_index= True, right_index= True)

# %% [markdown]
# Rows and Columns of the data sets

# %%
print('X Training Set :', Xtrain.shape)
print('Y Training Set :',Ytrain.shape)
print('X Testing Set  :',Xtest.shape)
print('Y Sample Set   :',Ysample.shape)
# Out:
# X Training Set : (31119, 13)
# Y Training Set : (31119, 1)
# X Testing Set  : (13752, 12)
# Y Sample Set   : (13752, 2)

# %% [markdown]
# Dataset structure
#
#     k is used to specify the train, s for the station and d for the day. One stop is given by the triplet k, s, d
#
# Contextual variables
#
#     date d: YYYYMMDD is the date of the train id run
#     train k: 1, 2, …, 55 train id (unique by day d)
#     station s: AA, AB, AC,… is the station id
#     hour: HH:00:00 is the time slot
#     way: 0, 1 is the train way with 0 (toward Paris) or 1 (toward suburb)
#     composition: 1, 2 is the number of train units (one or two)
#
# Lags variables
#
#     p1q0 ∈ [0,1] is the occupancy rate of the previous train k-1 at the same station s
#     p2q0 ∈ [0,1] is the occupancy rate of the second previous train k-2 at the same station s
#     p3q0 ∈ [0,1] is the occupancy rate of the third previous train k-3 at the same station s
#     p0q1 ∈ [0,1] is the occupancy rate of the same train k at the previous station s-1
#     p0q2 ∈ [0,1] is the occupancy rate of the same train k at the second previous station s-2
#     p0q3 ∈ [0,1] is the occupancy rate of the same train k at the third previous station s-3
#
# The lag variables are NA if the lag does not exist for the stop because of timetable structure

# %%
print(Xtrain.info())
print(Xtrain.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31119 entries, 0 to 31118
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         31119 non-null  object
#  1   train        31119 non-null  int64
#  2   way          31119 non-null  int64
#  3   station      31119 non-null  object
#  4   hour         27915 non-null  object
#  5   composition  31119 non-null  int64
#  6   p1q0         29067 non-null  float64
#  7   p2q0         26974 non-null  float64
#  8   p3q0         24935 non-null  float64
#  9   p0q1         27917 non-null  float64
#  10  p0q2         24720 non-null  float64
#  11  p0q3         21527 non-null  float64
#  12  p0q0         31119 non-null  float64
# dtypes: float64(7), int64(3), object(3)
# memory usage: 3.1+ MB
# None
#          date  train  way station      hour  composition  p1q0  p2q0  p3q0  \
# 0  2019-01-07      1    0      AD  06:00:00            2   NaN   NaN   NaN
# ...

# %% [markdown]
# Missing Values

# %%
Xtrain.isna().sum()
# Out:
# date              0
# train             0
# way               0
# station           0
# hour           3204
# composition       0
# p1q0           2052
# p2q0           4145
# p3q0           6184
# p0q1           3202
# p0q2           6399
# p0q3           9592
# p0q0              0
# dtype: int64

# %%
temp = Xtrain[Xtrain['p1q0'].isna() & Xtrain['p2q0'].isna() & Xtrain['p3q0'].isna() & Xtrain['p0q1'].isna() & Xtrain['p0q2'].isna() & Xtrain['p0q3'].isna()]
temp['station'].unique()
# Out:
# array(['AX', 'BG', 'AZ', 'AR'], dtype=object)

# %%
temp = Xtrain.loc[Xtrain['station']=='AX']
temp['hour'].unique()
temp
# Out:
#              date  train  way station hour  composition    p1q0      p2q0  \
# 406    2019-01-07      1    0      AX  NaN            2     NaN       NaN
# 407    2019-01-08      1    0      AX  NaN            2     NaN       NaN
# 408    2019-01-10      1    0      AX  NaN            2     NaN       NaN
# 409    2019-01-11      1    0      AX  NaN            2     NaN       NaN
# 410    2019-01-14      1    0      AX  NaN            2     NaN       NaN
# ...           ...    ...  ...     ...  ...          ...     ...       ...
# 30938  2019-05-13      9    0      AX  NaN            2  0.0840  0.110822
# 30939  2019-05-14      9    0      AX  NaN            2  0.0940  0.100000
# 30940  2019-05-15      9    0      AX  NaN            2  0.0910  0.085000
# 30941  2019-03-21      9    0      AX  NaN            2  0.1070  0.107000
# 30942  2019-01-30      9    0      AX  NaN            1  0.1076  0.096760
#
#          p3q0  p0q1  p0q2  p0q3   p0q0
# 406       NaN   NaN   NaN   NaN  0.045
# ...

# %%
temp = Xtrain.loc[Xtrain['station']=='BG']
print(temp['hour'].unique())
temp = temp[temp['hour'].isna() == False]
temp
# Out:
# [nan '06:00:00' '07:00:00' '08:00:00']
#              date  train  way station      hour  composition     p1q0    p2q0  \
# 13236  2019-01-07     29    0      BG  06:00:00            2  0.01500     NaN
# 13237  2019-01-08     29    0      BG  06:00:00            2  0.01700     NaN
# 13238  2019-01-09     29    0      BG  06:00:00            2  0.01665     NaN
# 13239  2019-01-10     29    0      BG  06:00:00            2  0.01000     NaN
# 13240  2019-01-11     29    0      BG  06:00:00            2  0.01665     NaN
# ...           ...    ...  ...     ...       ...          ...      ...     ...
# 17082  2019-05-09     33    0      BG  08:00:00            2  0.04780  0.0510
# 17083  2019-05-10     33    0      BG  08:00:00            2  0.05300  0.0500
# 17084  2019-05-15     33    0      BG  08:00:00            2  0.03400  0.0497
# 17085  2019-05-20     33    0      BG  08:00:00            2  0.05900  0.0540
# ...

# %%
temp = Xtrain.loc[Xtrain['station']=='AZ']
print(temp['hour'].unique())
temp = temp[temp['hour'].isna() == False]
temp
# Out:
# [nan '06:00:00' '07:00:00' '08:00:00' '09:00:00']
#              date  train  way station      hour  composition   p1q0    p2q0  \
# 21532  2019-01-07     45    0      AZ  06:00:00            2  0.048     NaN
# 21533  2019-01-08     45    0      AZ  06:00:00            2  0.068     NaN
# 21534  2019-01-10     45    0      AZ  06:00:00            2  0.061     NaN
# 21535  2019-01-11     45    0      AZ  06:00:00            2  0.049     NaN
# 21536  2019-01-14     45    0      AZ  06:00:00            2  0.061     NaN
# ...           ...    ...  ...     ...       ...          ...    ...     ...
# 28534  2019-05-16     55    0      AZ  09:00:00            2  0.159  0.5870
# 28535  2019-05-20     55    0      AZ  09:00:00            2  0.126  0.0990
# 28536  2019-04-17     55    0      AZ  09:00:00            2  0.102  0.1036
# 28537  2019-03-21     55    0      AZ  09:00:00            2  0.144  0.0670
# 28538  2019-01-30     55    0      AZ  09:00:00            2  0.067  0.1036
#
# ...

# %%
temp = Xtrain.loc[Xtrain['station']=='AR']
print(temp['hour'].unique())
temp
# Out:
# [nan]
#              date  train  way station hour  composition     p1q0    p2q0  \
# 21414  2019-01-07     45    0      AR  NaN            2      NaN     NaN
# 21415  2019-01-08     45    0      AR  NaN            2      NaN     NaN
# 21416  2019-01-10     45    0      AR  NaN            2      NaN     NaN
# 21417  2019-01-11     45    0      AR  NaN            2      NaN     NaN
# 21418  2019-01-14     45    0      AR  NaN            2      NaN     NaN
# ...           ...    ...  ...     ...  ...          ...      ...     ...
# 25522  2019-05-13     50    0      AR  NaN            2  0.04400  0.0410
# 25523  2019-05-14     50    0      AR  NaN            2  0.04000  0.0480
# 25524  2019-05-20     50    0      AR  NaN            2  0.04100  0.0460
# 25525  2019-03-21     50    0      AR  NaN            2  0.04300  0.0450
# 25526  2019-01-30     50    0      AR  NaN            2  0.04724  0.0444
#
#          p3q0  p0q1  p0q2  p0q3   p0q0
# 21414     NaN   NaN   NaN   NaN  0.021
# ...

# %%
Xtrain_date = Xtrain.copy()

Xtrain_date = Xtrain_date.drop('way', axis=1)

Xtrain_date = Xtrain_date[Xtrain_date['hour'].isna() == False]
Xtrain_date = Xtrain_date[Xtrain_date['station'] != 'AR']
Xtrain_date = Xtrain_date[Xtrain_date['station'] != 'AZ']

print('Original\n', Xtrain.isna().sum())
print('Removed Nan\n', Xtrain_date.isna().sum())
# Out:
# Original
#  date              0
# train             0
# way               0
# station           0
# hour           3204
# composition       0
# p1q0           2052
# p2q0           4145
# p3q0           6184
# p0q1           3202
# p0q2           6399
# p0q3           9592
# p0q0              0
# dtype: int64
# Removed Nan
#  date              0
# train             0
# station           0
# hour              0
# composition       0
# p1q0           1761
# p2q0           3564
# p3q0           5318
# p0q1            283
# p0q2           3480
# p0q3           6673
# p0q0              0
# dtype: int64

# %%
temp = Xtrain_date[Xtrain_date['p1q0'].isna() & Xtrain_date['p2q0'].isna() & Xtrain_date['p3q0'].isna() & Xtrain_date['p0q1'].isna() & Xtrain_date['p0q2'].isna() & Xtrain_date['p0q3'].isna()]
temp
# Out:
# Empty DataFrame
# Columns: [date, train, station, hour, composition, p1q0, p2q0, p3q0, p0q1, p0q2, p0q3, p0q0]
# Index: []

# %% [markdown]
# Handle missing data in each column

# %%
hours = list(Xtrain_date['hour'].unique())

for hour in hours:
    temp = Xtrain_date[Xtrain_date['hour'] == hour]
    print(f"Hour: {hour}\n{temp[['p1q0','p2q0','p3q0','p0q1','p0q2','p0q3']].isna().sum()}")
# Out:
# Hour: 06:00:00
# p1q0    1761
# p2q0    3252
# p3q0    4075
# p0q1     110
# p0q2     917
# p0q3    1601
# dtype: int64
# Hour: 07:00:00
# p1q0       0
# p2q0     312
# p3q0    1243
# p0q1     115
# p0q2    1237
# p0q3    2406
# dtype: int64
# Hour: 08:00:00
# p1q0       0
# p2q0       0
# p3q0       0
# p0q1      58
# p0q2    1164
# p0q3    2316
# dtype: int64
# Hour: 09:00:00
# p1q0      0
# p2q0      0
# p3q0      0
# p0q1      0
# p0q2    162
# p0q3    350
# dtype: int64
# Hour: 11:00:00
# p1q0    0
# p2q0    0
# p3q0    0
# p0q1    0
# p0q2    0
# p0q3    0
# dtype: int64

# %%
Xtrain_date.loc[(Xtrain_date['p1q0'].isna()) & (Xtrain_date['p2q0'].isna()) & (Xtrain_date['p3q0'].isna()), ['p1q0','p2q0','p3q0']] = 0
Xtrain_date.loc[(Xtrain_date['p1q0'].isna() == False) & (Xtrain_date['p2q0'].isna()) & (Xtrain_date['p3q0'].isna()), ['p2q0','p3q0']] = 0
for i, row in Xtrain_date.iterrows():
    if math.isnan(row['p3q0']):
        diff = row['p1q0'] - row['p2q0']
        Xtrain_date.at[i,'p3q0'] = diff

print(Xtrain_date['p1q0'].isna().sum())
print(Xtrain_date['p2q0'].isna().sum())
print(Xtrain_date['p3q0'].isna().sum())
# Out:
# 0
# 0
# 0

# %%
Xtrain_date.loc[(Xtrain_date['p0q1'].isna()) & (Xtrain_date['p0q2'].isna()) & (Xtrain_date['p0q3'].isna()), ['p0q1','p0q2','p0q3']] = 0
Xtrain_date.loc[(Xtrain_date['p0q1'].isna() == False) & (Xtrain_date['p0q2'].isna()) & (Xtrain_date['p0q3'].isna()), ['p0q2','p0q3']] = 0
for i, row in Xtrain_date.iterrows():
    if math.isnan(row['p0q3']):
        diff = row['p0q1'] - row['p0q2']
        Xtrain_date.at[i,'p0q3'] = diff

print(Xtrain_date['p0q1'].isna().sum())
print(Xtrain_date['p0q2'].isna().sum())
print(Xtrain_date['p0q3'].isna().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# Unique Values
#
# Trains ONLY going to paris
# Trains have either 2 or 1 carts

# %%
print(Xtrain['way'].unique())
print(Xtrain['composition'].unique())
# Out:
# [0]
# [2 1]

# %% [markdown]
# Add Weekday and Month to dataset

# %%
# convert Time to Datetime
Xtrain_date['date'] = pd.to_datetime(Xtrain_date['date'], format='%Y/%m/%d')

# Add new column for weekday
weekday = Xtrain_date['date'].dt.day_name()
month = Xtrain_date['date'].dt.month_name()
Xtrain_date.insert(1,'weekday',weekday)
Xtrain_date.insert(2,'month',month)
Xtrain_date
# Out:
#             date    weekday    month  train station      hour  composition  \
# 0     2019-01-07     Monday  January      1      AD  06:00:00            2
# 1     2019-01-08    Tuesday  January      1      AD  06:00:00            2
# 2     2019-01-10   Thursday  January      1      AD  06:00:00            2
# 3     2019-01-11     Friday  January      1      AD  06:00:00            2
# 4     2019-01-14     Monday  January      1      AD  06:00:00            2
# ...          ...        ...      ...    ...     ...       ...          ...
# 31114 2019-05-13     Monday      May      9      BE  08:00:00            2
# 31115 2019-05-14    Tuesday      May      9      BE  08:00:00            2
# 31116 2019-05-15  Wednesday      May      9      BE  08:00:00            2
# 31117 2019-03-21   Thursday    March      9      BE  08:00:00            2
# 31118 2019-01-30  Wednesday  January      9      BE  08:00:00            1
#
#         p1q0     p2q0      p3q0   p0q1   p0q2   p0q3   p0q0
# ...

# %% [markdown]
# Looking at previous trains at 6am

# %%
six_am = Xtrain_date.loc[Xtrain_date['hour']=='06:00:00']
print(six_am.describe())
# Out:
#              train  composition         p1q0         p2q0         p3q0  \
# count  4936.000000       4936.0  4936.000000  4936.000000  4936.000000
# mean     23.196718          2.0     0.071548     0.042302     0.019739
# std      15.523228          0.0     0.083269     0.066766     0.074131
# min       1.000000          2.0     0.000000     0.000000    -0.205000
# 25%      12.000000          2.0     0.000000     0.000000     0.000000
# 50%      23.000000          2.0     0.040000     0.000000     0.000000
# 75%      34.000000          2.0     0.125000     0.090274     0.000000
# max      51.000000          2.0     0.665000     0.319000     0.509000
#
#               p0q1         p0q2         p0q3         p0q0
# count  4936.000000  4936.000000  4936.000000  4936.000000
# mean      0.097338     0.084781     0.066931     0.133285
# std       0.067848     0.072704     0.071038     0.073568
# min       0.000000     0.000000    -0.075000     0.010000
# ...

# %% [markdown]
# Filling in NA's with 0
#
# For 1st train -> fill with 0

# %%
print('Original',Xtrain.isna().sum())
Xtrain_date.loc[(Xtrain_date['hour'] == '06:00:00') & (Xtrain_date['p1q0'].isna()), 'p1q0'] = 0
Xtrain_date.loc[(Xtrain_date['hour'] == '06:00:00') & (Xtrain_date['p2q0'].isna()), 'p2q0'] = 0
Xtrain_date.loc[(Xtrain_date['hour'] == '06:00:00') & (Xtrain_date['p3q0'].isna()), 'p3q0'] = 0
print('Replaced with 0',Xtrain_date.isna().sum())
Xtrain_date
# Out:
# Original date              0
# train             0
# way               0
# station           0
# hour           3204
# composition       0
# p1q0           2052
# p2q0           4145
# p3q0           6184
# p0q1           3202
# p0q2           6399
# p0q3           9592
# p0q0              0
# dtype: int64
# Replaced with 0 date           0
# weekday        0
# month          0
# train          0
# station        0
# hour           0
# composition    0
# p1q0           0
# p2q0           0
# p3q0           0
# p0q1           0
# p0q2           0
# p0q3           0
# p0q0           0
# dtype: int64
#             date    weekday    month  train station      hour  composition  \
# 0     2019-01-07     Monday  January      1      AD  06:00:00            2
# 1     2019-01-08    Tuesday  January      1      AD  06:00:00            2
# 2     2019-01-10   Thursday  January      1      AD  06:00:00            2
# 3     2019-01-11     Friday  January      1      AD  06:00:00            2
# ...

# %%
Xtrain_date.groupby(['train','hour']).size()
# Out:
# train  hour
# 1      06:00:00    577
#        07:00:00      3
# 2      06:00:00    349
#        07:00:00    211
# 3      06:00:00    108
#                   ...
# 53     07:00:00    237
#        08:00:00    183
# 54     08:00:00    420
# 55     08:00:00    230
#        09:00:00    190
# Length: 97, dtype: int64

# %% [markdown]
# Plot of p1q0 & p0q1 for 6am train
#
# Justifies why we use median to fill Nan values

# %%
Xtrain_date['hour'].unique()
# Out:
# array(['06:00:00', '07:00:00', '08:00:00', '09:00:00', '11:00:00'],
#       dtype=object)

# %%
Xtrain_date.groupby('hour').size()
# Out:
# hour
# 06:00:00    4936
# 07:00:00    9827
# 08:00:00    9794
# 09:00:00    2707
# 11:00:00       2
# dtype: int64

# %% [markdown]
# number of trains per date, station, hour

# %%
print(Xtrain_date.groupby(['date','station','hour']).size())
# Out:
# date        station  hour
# 2019-01-07  AA       06:00:00    1
#                      07:00:00    1
#                      08:00:00    1
#             AB       06:00:00    3
#                      07:00:00    2
#                                 ..
# 2019-05-20  BI       08:00:00    2
#             BJ       06:00:00    1
#                      07:00:00    2
#                      08:00:00    2
#                      09:00:00    1
# Length: 7975, dtype: int64

# %%
print(Xtrain_date.groupby(['train','hour']).size())
# Out:
# train  hour
# 1      06:00:00    577
#        07:00:00      3
# 2      06:00:00    349
#        07:00:00    211
# 3      06:00:00    108
#                   ...
# 53     07:00:00    237
#        08:00:00    183
# 54     08:00:00    420
# 55     08:00:00    230
#        09:00:00    190
# Length: 97, dtype: int64

# %%
Xtrain_date[Xtrain_date['hour'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, weekday, month, train, station, hour, composition, p1q0, p2q0, p3q0, p0q1, p0q2, p0q3, p0q0]
# Index: []

# %%
Xtrain.groupby(['composition']).size()
# Out:
# composition
# 1       11
# 2    31108
# dtype: int64

# %% [markdown]
# Number of weekday entry points

# %%
print(f'Unique Weekdays: {Xtrain_date["weekday"].unique()}')
sns.countplot(y=Xtrain_date['weekday'])
# Out:
# Unique Weekdays: ['Monday' 'Tuesday' 'Thursday' 'Friday' 'Wednesday']
# <AxesSubplot:xlabel='count', ylabel='weekday'>

# %% [markdown]
# Number of Month entry points

# %%
print(f'Unique Montsh: {Xtrain_date["month"].unique()}')
sns.countplot(y=Xtrain_date['month'])
# Out:
# Unique Montsh: ['January' 'February' 'March' 'April' 'May']
# <AxesSubplot:xlabel='count', ylabel='month'>

# %% [markdown]
# Number of hour entry points - most active hours?

# %%
print(f'Unique Times: {Xtrain_date["hour"].unique()}')
sns.countplot(y=Xtrain_date['hour'])
# Out:
# Unique Times: ['06:00:00' '07:00:00' '08:00:00' '09:00:00' '11:00:00']
# <AxesSubplot:xlabel='count', ylabel='hour'>

# %% [markdown]
# ### Correlation Matrix

# %%
Xtrain_date['hour'] = pd.to_datetime(Xtrain_date['hour'], format='%H:%M:%S')
Xtrain_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27266 entries, 0 to 31118
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         27266 non-null  datetime64[ns]
#  1   weekday      27266 non-null  object
#  2   month        27266 non-null  object
#  3   train        27266 non-null  int64
#  4   station      27266 non-null  object
#  5   hour         27266 non-null  datetime64[ns]
#  6   composition  27266 non-null  int64
#  7   p1q0         27266 non-null  float64
#  8   p2q0         27266 non-null  float64
#  9   p3q0         27266 non-null  float64
#  10  p0q1         27266 non-null  float64
#  11  p0q2         27266 non-null  float64
#  12  p0q3         27266 non-null  float64
#  13  p0q0         27266 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(3)
# memory usage: 4.1+ MB

# %%
Xtrain_date['intHour'] = Xtrain_date['hour'].apply(lambda x: int(x.hour))

# %%
sns.heatmap(Xtrain_date.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Models
#
# Baseline Models:
#
# *   Model using P*q0 (different train - same station)
# *   Model using p0q* (same train - different station)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Model 1 -> P*q0 (Different train - same station)

# %%
model_1 = Xtrain_date.copy()
columns = ['date','weekday','month','train','station','hour','composition','p0q1','p0q2','p0q3']
model_1 = model_1.drop(columns=columns, axis= 1)
features = model_1.iloc[:,:-1]
target = model_1.iloc[:,-1:]

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

LR = LinearRegression()
LR.fit(x_train,y_train)

y_prediction =  LR.predict(x_test)
y_prediction

score=r2_score(y_test,y_prediction)
mse = mean_squared_error(y_test, y_prediction)
print(f'r2 socre is:            {score}')
print(f'mean_sqrd_error is:     {mse}')

x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, y_prediction, label="predicted")
plt.title("Train Forcasting")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# r2 socre is:            0.4299142111238933
# mean_sqrd_error is:     0.45771466354983964

# %%
model_2 = Xtrain_date.copy()
columns = ['date','weekday','month','train','station','hour','composition','p1q0','p2q0','p3q0']
model_2 = model_2.drop(columns=columns, axis= 1)
features = model_2.iloc[:,:-1]
target = model_2.iloc[:,-1:]

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

LR = LinearRegression()
LR.fit(x_train,y_train)

y_prediction =  LR.predict(x_test)
y_prediction

score=r2_score(y_test,y_prediction)
mse = mean_squared_error(y_test, y_prediction)
print(f'r2 socre is:            {score}')
print(f'mean_sqrd_error is:     {mse}')

x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, y_prediction, label="predicted")
plt.title("Train Forcasting")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# r2 socre is:            0.08793190648832427
# mean_sqrd_error is:     0.7322879270140267

# %%
from sklearn.linear_model import SGDRegressor
import matplotlib.pyplot as plt

# %%
model_1 = Xtrain_date.copy()
columns = ['date','weekday','month','train','station','hour','composition','p0q1','p0q2','p0q3']
model_1 = model_1.drop(columns=columns, axis= 1)
features = model_1.iloc[:,:-1]
target = model_1.iloc[:,-1:]

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

sgdr = SGDRegressor()
sgdr.fit(x_train, y_train)

score = sgdr.score(x_train, y_train)
print("R-squared:", score)

y_prediction = sgdr.predict(x_test)

mse = mean_squared_error(y_test, y_prediction)
print("MSE: ", mse)
print("RMSE: ", mse**(1/2.0))

x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, y_prediction, label="predicted")
plt.title("Train Forcasting")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# R-squared: 0.42464336663189206
# MSE:  0.46128141049315097
# RMSE:  0.6791770096912519
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model_2 = Xtrain_date.copy()
columns = ['date','weekday','month','train','station','hour','composition','p1q0','p2q0','p3q0']
model_2 = model_2.drop(columns=columns, axis= 1)
features = model_2.iloc[:,:-1]
target = model_2.iloc[:,-1:]

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

sgdr = SGDRegressor()
sgdr.fit(x_train, y_train)

score = sgdr.score(x_train, y_train)
print("R-squared:", score)

y_prediction = sgdr.predict(x_test)

mse = mean_squared_error(y_test, y_prediction)
print("MSE: ", mse)
print("RMSE: ", mse**(1/2.0))

x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, y_prediction, label="predicted")
plt.title("Train Forcasting")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# R-squared: 0.08428905575882772
# MSE:  0.7345491806172794
# RMSE:  0.8570584464418278
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
